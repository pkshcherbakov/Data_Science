# %% [markdown]
# ## Made by Shcherbakov Pavel

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
import natasha as nt
from ipymarkup import show_line_markup
from yargy.tokenizer import MorphTokenizer
from yargy.predicates import gram, eq, normalized
from yargy import Parser, rule
from yargy.pipelines import morph_pipeline

tokenizer = MorphTokenizer()

# %%
raw_input = pd.read_csv(r'F:/DataScience/Educational/Собеседования/Bewise/test_data.csv')

# %%
#Total number of dialogs
num_dialog = raw_input['dlg_id'].unique()
num_dialog
# Out:
# array([0, 1, 2, 3, 4, 5], dtype=int64)

# %%
dialog_dict_full = {}
# Full dialog dict with dlg_id as a key and tuple (line_n, text) as value
def set_full_dialog(df):
    for elem in num_dialog:
        condition = raw_input[(raw_input['dlg_id'] == elem)]['text'].values
        a = [(i, value) for (i, value) in enumerate(condition)]
        dialog_dict_full[elem] = a
    return dialog_dict_full

# %%
dialog_dict_full_str = {}
# Full dialog dict with dlg_id as a key and text as value
def set_full_dialog_str(df):
    for elem in num_dialog:
        curr_dialog = []
        condition = raw_input[(raw_input['dlg_id'] == elem)]['text'].values
        for text in condition:
            curr_dialog.append(text)
        str_curr_dialog = '. '.join(curr_dialog)
        dialog_dict_full_str[elem] = str_curr_dialog
    return dialog_dict_full_str

# %%
# We are interested in manager phrases only 
manager_greet, manager_bye = {}, {}
def set_manager_help(df):
    for elem in num_dialog:
        dialog_greet, dialog_bye = [], []
        condition = raw_input[(raw_input['role'] == 'manager') & (raw_input['dlg_id'] == elem)]['text'].values
        for i, a in enumerate(condition):
            if i < 3:
# First three sentenses for identifying greeting, introducing, company name and manager name
                dialog_greet.append(a)
            elif i >= len(condition) - 3:
# Last three sentences for identifying goodbye
                dialog_bye.append(a)
        manager_greet[elem] = '. '.join(dialog_greet)
        manager_bye[elem] = '. '.join(dialog_bye)
    return manager_greet, manager_bye

# %%
dialog_dict_full = set_full_dialog(raw_input)
dialog_dict_full_str = set_full_dialog_str(raw_input)
manager_greet, manager_bye = set_manager_help(raw_input)

# %%
#Rules for entity extraction from text
#Greet rule
GREET = morph_pipeline([
    'Здравствуй',
    'Здравствуйте',
    'Доброго дня',
    'Добрый вечер',
    'Доброе утро',
    'Привет',
    'Приветствую',
    'Доброго времени суток'
])

#Introduce rule
INT_PHR = morph_pipeline([
    'Меня зовут',
    'Моё имя',
    'Меня',
    'Это',
    'Вас беспокоит',
    'Я'
])
#Bye rule
BYE = morph_pipeline([
    'До свидания',
    'Пока',
    'До скорого',
    'Всего доброго',
    'Всего хорошего',
    'Хорошего дня',
    'Доброй ночи',
    'До встречи',
    'Удачи',
])
#POS selection
CONJ = gram('CONJ')
PRCL = gram('PRCL')
INTJ = gram('INTJ')
ADJ =  gram('ADJF')
NOUN = gram('NOUN')
VERB = gram('VERB')
ADVB = gram('ADVB')
#Name selection
NAME = gram('Name')
#Company
COMP = morph_pipeline([
    'Компания',
    'Кампания', # For the case of mistake
    'Организация',
    'Фирма',
    'Из',
    'Предприятие'
    ])

INTRO = rule(INT_PHR, NAME)
BYEPARSE = rule(BYE)
NAMEPARSE = rule(NAME)
# Company name should end with NOUN
COMPANY = rule(COMP, VERB.optional(),ADJ.repeatable().optional(), \
               CONJ.optional(), PRCL.optional(), INTJ.optional(), NOUN)
COMPANYPARSE = rule(VERB.optional(),ADJ.repeatable().optional(), \
               CONJ.optional(), PRCL.optional(), INTJ.optional(), NOUN)

# %%
span_greet, span_intro, span_company, span_bye = {}, {}, {}, {}
res_greet, res_intro, res_name, res_company, res_bye = {}, {}, {}, {}, {}
#Entity parsing
def parse(cond, manager_list):
    span_list = {}
    parser = Parser(cond)
    for elem in num_dialog:
        temp_list = []
        all_greet = list(parser.findall(manager_list[elem]))
        spans = [elem.span for elem in all_greet]
        if not spans:
            print(f"No entity is found in {elem} dialog")
        for el in spans:
            temp_list.append(el)
        span_list[elem] = temp_list
       #show_line_markup(manager_list[elem], spans)
    return span_list

# %%
span_greet = parse(GREET, manager_greet)
print('-------------------------------------')
span_intro = parse(INTRO, manager_greet)
print('-------------------------------------')
span_bye = parse(BYEPARSE, manager_bye)
print('-------------------------------------')
span_company = parse(COMPANY, manager_greet)
# Out:
# No entity is found in 4 dialog
# No entity is found in 5 dialog
# -------------------------------------
# No entity is found in 4 dialog
# -------------------------------------
# -------------------------------------
# No entity is found in 4 dialog
# No entity is found in 5 dialog

# %%
def get_final_dict(span_list, manager_list):
    dict_word, dict_sent, final_dict = {}, {}, {}
    for key, value in span_list.items():
        wordlist = []
        for elem in value:
            start_idx, end_idx = elem
            word = manager_list[key][start_idx:end_idx]
            wordlist.append(word)
        dict_word[key] = wordlist
    # dict_word -- dict with dlg_id as key and list of words as values
    for key in dict_word.keys():
        sentlist = []
        sent_list = manager_list[key].split('. ')
        for sent in sent_list:
            for elem in dict_word[key]:
                if elem in sent:
                    full_sent = sent
                    sentlist.append(full_sent)
            dict_sent[key] = sentlist
    # dict_sent -- dict with dlg_id as key and list of sentences as value
    for key, sent in dict_sent.items():
        idxlist = []
        for elem in sent:
            for num, phrase in dialog_dict_full[key]:
                if elem == phrase:
                    idxlist.append(num)
            final_dict[key] = idxlist
# final_dict -- dict with dlg_id as key and list of indexes of entity as value
    return final_dict

# %%
# Auxiliary dict for entity extraction (name and company)
def get_single_info(span_list, manager_list):
    dict_word = {}
    for key, value in span_list.items():
        if value:
            for elem in value:
                start_idx, end_idx = elem
                word = '. '.join(manager_list[key])[start_idx:end_idx]
                dict_word[key] = word
        else:
            dict_word[key] = 'Unknown'
    return dict_word

# %%
# Auxiliary dict for entity extraction (phrases of greet, introducing and bye)
def get_mul_info(span_list, manager_list):
    dict_word = {}
    for key, value in span_list.items():
        wordlist = []
        for elem in value:
            start_idx, end_idx = elem
            word = manager_list[key][start_idx:end_idx]
            wordlist.append(word)
        dict_word[key] = wordlist
    return dict_word

# %%
res_greet = get_final_dict(span_greet, manager_greet)
res_intro = get_final_dict(span_intro, manager_greet)
res_bye = get_final_dict(span_bye, manager_bye)
res_name  = get_mul_info(span_intro, manager_greet)
res_company  = get_mul_info(span_company, manager_greet)

# %%
#Help function for name and company extraction
def parse_name_company(parse, res_list):
    parser = Parser(parse)
    idx_dict = {}
    for key, value in res_list.items():
        temp_list = []
        all_greet = list(parser.findall('. '.join(value)))
        spans = [elem.span for elem in all_greet]
        for el in spans:
            temp_list.append(el)
        idx_dict[key] = temp_list
    return idx_dict

# %%
#List of manager names
idx_dict = parse_name_company(NAMEPARSE, res_name)   
manager_names = get_single_info(idx_dict, res_name)
manager_names
# Out:
# {0: 'ангелина',
#  1: 'ангелина',
#  2: 'ангелина',
#  3: 'максим',
#  4: 'Unknown',
#  5: 'анастасия'}

# %%
#List of company names
idx_dict = parse_name_company(COMPANYPARSE, res_company)   
company_names = get_single_info(idx_dict, res_company)
company_names
# Out:
# {0: 'диджитал бизнес',
#  1: 'диджитал бизнес',
#  2: 'диджитал бизнес',
#  3: 'китобизнес',
#  4: 'Unknown',
#  5: 'Unknown'}

# %%
def set_result(df, column, res_dict):
    df[column] = False
    for dlg_id, line_n in res_dict.items():
        for elem in line_n:
            condition = (df['dlg_id'] == dlg_id) & (df['line_n'] == elem) & \
            (df['role'] == 'manager')
            df.loc[condition, [column]] = True
    return df

# %%
df = set_result(raw_input, 'Greet', res_greet)
df = set_result(raw_input, 'Introduce', res_intro)
df = set_result(raw_input, 'Bye', res_bye)

# %%
df['Greet and bye'] = False
for elem in num_dialog:
    cond1 = df[df['dlg_id'] == elem]['Greet'].any()
    cond2 = df[df['dlg_id'] == elem]['Bye'].any()
    cond3 = df['dlg_id'] == elem
    df.loc[cond1 & cond2 & cond3, ['Greet and bye']] = True

# %%
df
# Out:
#      dlg_id  line_n     role  \
# 0         0       0   client
# 1         0       1  manager
# 2         0       2   client
# 3         0       3  manager
# 4         0       4   client
# 5         0       5  manager
# 6         0       6   client
# 7         0       7   client
# 8         0       8  manager
# 9         0       9   client
# 10        0      10   client
# 11        0      11  manager
# 12        0      12   client
# 13        0      13   client
# 14        0      14   client
# 15        0      15  manager
# 16        0      16   client
# 17        0      17   client
# 18        0      18   client
# 19        0      19   client
# 20        0      20   client
# 21        0      21   client
# 22        0      22   client
# 23        0      23   client
# 24        0      24   client
# 25        0      25   client
# 26        0      26   client
# 27        0      27   client
# 28        0      28   client
# 29        0      29  manager
# 30        0      30   client
# 31        0      31   client
# 32        0      32   client
# 33        0      33   client
# 34        0      34  manager
# 35        0      35   client
# 36        0      36  manager
# 37        0      37   client
# 38        0      38   client
# 39        0      39   client
# 40        0      40   client
# 41        0      41   client
# 42        0      42   client
# 43        0      43   client
# 44        0      44   client
# 45        0      45  manager
# 46        0      46   client
# 47        0      47   client
# 48        0      48   client
# 49        0      49   client
# 50        0      50   client
# 51        0      51   client
# 52        0      52   client
# 53        0      53   client
# 54        0      54   client
# 55        0      55   client
# 56        0      56   client
# 57        0      57   client
# 58        0      58   client
# 59        0      59   client
# 60        0      60   client
# 61        0      61   client
# 62        0      62  manager
# 63        0      63   client
# 64        0      64   client
# 65        0      65   client
# 66        0      66   client
# 67        0      67   client
# 68        0      68   client
# 69        0      69   client
# 70        0      70   client
# 71        0      71   client
# 72        0      72   client
# 73        0      73   client
# 74        0      74   client
# 75        0      75   client
# 76        0      76   client
# 77        0      77  manager
# 78        0      78   client
# 79        0      79   client
# 80        0      80   client
# 81        0      81   client
# 82        0      82   client
# 83        0      83   client
# 84        0      84   client
# 85        0      85   client
# 86        0      86   client
# 87        0      87   client
# 88        0      88   client
# 89        0      89   client
# 90        0      90   client
# 91        0      91   client
# 92        0      92  manager
# 93        0      93   client
# 94        0      94  manager
# 95        0      95   client
# 96        0      96   client
# 97        0      97   client
# 98        0      98   client
# 99        0      99   client
# 100       0     100   client
# 101       0     101   client
# 102       0     102   client
# 103       0     103   client
# 104       0     104   client
# 105       0     105   client
# 106       0     106  manager
# 107       0     107   client
# 108       0     108  manager
# 109       1       0   client
# 110       1       1  manager
# 111       1       2  manager
# 112       1       3  manager
# 113       1       4  manager
# 114       1       5   client
# 115       1       6  manager
# 116       1       7   client
# 117       1       8   client
# 118       1       9   client
# 119       1      10  manager
# 120       1      11   client
# 121       1      12  manager
# 122       1      13   client
# 123       1      14   client
# 124       1      15   client
# 125       1      16   client
# 126       1      17  manager
# 127       1      18   client
# 128       1      19  manager
# 129       1      20   client
# 130       1      21  manager
# 131       1      22   client
# 132       1      23  manager
# 133       1      24   client
# 134       1      25   client
# 135       1      26  manager
# 136       1      27   client
# 137       1      28  manager
# 138       1      29  manager
# 139       1      30   client
# 140       1      31  manager
# 141       1      32   client
# 142       1      33   client
# 143       1      34   client
# 144       1      35  manager
# 145       1      36  manager
# 146       1      37  manager
# 147       1      38   client
# 148       1      39  manager
# 149       1      40  manager
# 150       1      41  manager
# 151       1      42   client
# 152       1      43  manager
# 153       1      44  manager
# 154       1      45   client
# 155       1      46  manager
# 156       1      47  manager
# 157       1      48   client
# 158       1      49  manager
# 159       1      50   client
# 160       1      51  manager
# 161       1      52   client
# 162       1      53  manager
# 163       1      54  manager
# 164       2       0   client
# 165       2       1   client
# 166       2       2  manager
# 167       2       3  manager
# 168       2       4  manager
# 169       2       5   client
# 170       2       6  manager
# 171       2       7  manager
# 172       2       8   client
# 173       2       9  manager
# 174       2      10   client
# 175       2      11  manager
# 176       2      12   client
# 177       2      13  manager
# 178       2      14  manager
# 179       2      15   client
# 180       2      16   client
# 181       2      17   client
# 182       2      18  manager
# 183       2      19   client
# 184       2      20  manager
# 185       2      21   client
# 186       2      22  manager
# 187       2      23  manager
# 188       2      24  manager
# 189       2      25   client
# 190       2      26   client
# 191       2      27  manager
# 192       2      28   client
# 193       2      29  manager
# 194       2      30   client
# 195       2      31   client
# 196       2      32   client
# 197       2      33  manager
# 198       2      34  manager
# 199       2      35   client
# 200       2      36   client
# 201       2      37   client
# 202       2      38   client
# 203       2      39   client
# 204       2      40   client
# 205       2      41  manager
# 206       2      42   client
# 207       2      43  manager
# 208       2      44  manager
# 209       2      45   client
# 210       2      46  manager
# 211       2      47   client
# 212       2      48   client
# 213       2      49  manager
# 214       2      50  manager
# 215       2      51   client
# 216       2      52  manager
# 217       2      53   client
# 218       2      54  manager
# 219       2      55   client
# 220       2      56   client
# 221       2      57   client
# 222       2      58  manager
# 223       2      59   client
# 224       2      60   client
# 225       2      61  manager
# 226       2      62   client
# 227       2      63   client
# 228       2      64  manager
# 229       2      65  manager
# 230       2      66   client
# 231       2      67  manager
# 232       2      68   client
# 233       2      69  manager
# 234       2      70   client
# 235       2      71  manager
# 236       2      72   client
# 237       2      73  manager
# 238       2      74   client
# 239       2      75  manager
# 240       2      76  manager
# 241       2      77  manager
# 242       2      78   client
# 243       2      79   client
# 244       2      80  manager
# 245       2      81   client
# 246       2      82  manager
# 247       2      83   client
# 248       2      84  manager
# 249       3       0   client
# 250       3       1  manager
# 251       3       2  manager
# 252       3       3   client
# 253       3       4  manager
# 254       3       5   client
# 255       3       6   client
# 256       3       7  manager
# 257       3       8   client
# 258       3       9   client
# 259       3      10   client
# 260       3      11  manager
# 261       3      12   client
# 262       3      13   client
# 263       3      14   client
# 264       3      15   client
# 265       3      16  manager
# 266       3      17  manager
# 267       3      18   client
# 268       3      19  manager
# 269       3      20   client
# 270       3      21   client
# 271       3      22   client
# 272       3      23   client
# 273       3      24  manager
# 274       3      25   client
# 275       3      26  manager
# 276       3      27   client
# 277       3      28  manager
# 278       3      29  manager
# 279       3      30   client
# 280       3      31   client
# 281       3      32   client
# 282       3      33  manager
# 283       3      34   client
# 284       3      35  manager
# 285       3      36  manager
# 286       3      37  manager
# 287       3      38   client
# 288       3      39   client
# 289       3      40   client
# 290       3      41   client
# 291       3      42  manager
# 292       3      43  manager
# 293       3      44  manager
# 294       3      45   client
# 295       3      46   client
# 296       3      47  manager
# 297       3      48   client
# 298       3      49  manager
# 299       3      50   client
# 300       3      51  manager
# 301       3      52   client
# 302       4       0   client
# 303       4       1   client
# 304       4       2   client
# 305       4       3  manager
# 306       4       4   client
# 307       4       5   client
# 308       4       6  manager
# 309       4       7   client
# 310       4       8  manager
# 311       4       9  manager
# 312       4      10   client
# 313       4      11   client
# 314       4      12  manager
# 315       4      13   client
# 316       4      14  manager
# 317       4      15   client
# 318       4      16   client
# 319       4      17  manager
# 320       4      18   client
# 321       4      19   client
# 322       4      20   client
# 323       4      21   client
# 324       4      22  manager
# 325       4      23   client
# 326       4      24   client
# 327       4      25  manager
# 328       4      26   client
# 329       4      27  manager
# 330       4      28   client
# 331       4      29  manager
# 332       4      30   client
# 333       4      31  manager
# 334       4      32  manager
# 335       4      33  manager
# 336       4      34   client
# 337       5       0   client
# 338       5       1  manager
# 339       5       2   client
# 340       5       3  manager
# 341       5       4   client
# 342       5       5   client
# 343       5       6  manager
# 344       5       7   client
# 345       5       8   client
# 346       5       9  manager
# 347       5      10   client
# 348       5      11   client
# 349       5      12  manager
# 350       5      13   client
# 351       5      14  manager
# 352       5      15   client
# 353       5      16  manager
# 354       5      17   client
# 355       5      18   client
# 356       5      19  manager
# 357       5      20  manager
# 358       5      21   client
# 359       5      22  manager
# 360       5      23   client
# 361       5      24   client
# 362       5      25  manager
# 363       5      26   client
# 364       5      27   client
# 365       5      28  manager
# 366       5      29  manager
# 367       5      30  manager
# 368       5      31  manager
# 369       5      32  manager
# 370       5      33  manager
# 371       5      34  manager
# 372       5      35  manager
# 373       5      36  manager
# 374       5      37  manager
# 375       5      38   client
# 376       5      39  manager
# 377       5      40   client
# 378       5      41  manager
# 379       5      42  manager
# 380       5      43  manager
# 381       5      44   client
# 382       5      45  manager
# 383       5      46   client
# 384       5      47  manager
# 385       5      48   client
# 386       5      49   client
# 387       5      50  manager
# 388       5      51   client
# 389       5      52   client
# 390       5      53  manager
# 391       5      54   client
# 392       5      55   client
# 393       5      56   client
# 394       5      57   client
# 395       5      58  manager
# 396       5      59  manager
# 397       5      60  manager
# 398       5      61  manager
# 399       5      62   client
# 400       5      63  manager
# 401       5      64  manager
# 402       5      65  manager
# 403       5      66   client
# 404       5      67  manager
# 405       5      68   client
# 406       5      69  manager
# 407       5      70   client
# 408       5      71  manager
# 409       5      72  manager
# 410       5      73  manager
# 411       5      74   client
# 412       5      75   client
# 413       5      76  manager
# 414       5      77  manager
# 415       5      78  manager
# 416       5      79  manager
# 417       5      80   client
# 418       5      81  manager
# 419       5      82   client
# 420       5      83  manager
# 421       5      84  manager
# 422       5      85   client
# 423       5      86  manager
# 424       5      87   client
# 425       5      88  manager
# 426       5      89   client
# 427       5      90   client
# 428       5      91   client
# 429       5      92  manager
# 430       5      93  manager
# 431       5      94  manager
# 432       5      95   client
# 433       5      96  manager
# 434       5      97  manager
# 435       5      98  manager
# 436       5      99  manager
# 437       5     100   client
# 438       5     101  manager
# 439       5     102   client
# 440       5     103   client
# 441       5     104  manager
# 442       5     105  manager
# 443       5     106   client
# 444       5     107  manager
# 445       5     108   client
# 446       5     109   client
# 447       5     110  manager
# 448       5     111  manager
# 449       5     112   client
# 450       5     113  manager
# 451       5     114  manager
# 452       5     115   client
# 453       5     116  manager
# 454       5     117  manager
# 455       5     118   client
# 456       5     119  manager
# 457       5     120   client
# 458       5     121   client
# 459       5     122   client
# 460       5     123  manager
# 461       5     124   client
# 462       5     125  manager
# 463       5     126   client
# 464       5     127  manager
# 465       5     128   client
# 466       5     129  manager
# 467       5     130   client
# 468       5     131  manager
# 469       5     132   client
# 470       5     133  manager
# 471       5     134  manager
# 472       5     135  manager
# 473       5     136  manager
# 474       5     137   client
# 475       5     138  manager
# 476       5     139  manager
# 477       5     140   client
# 478       5     141   client
# 479       5     142  manager
#
#                                                   text  Greet  Introduce  \
# 0                                                 Алло  False      False
# 1                                    Алло здравствуйте   True      False
# 2                                          Добрый день  False      False
# 3    Меня зовут ангелина компания диджитал бизнес з...  False       True
# 4                                                  Ага  False      False
# 5    Угу ну возможно вы рассмотрите и другие вариан...  False      False
# 6    Да мы работаем с компанией которая нам подлива...  False      False
# 7    Как как бы уже до этого момента работаем все у...  False      False
# 8        Угу а на что вы обращаете внимание при выборе  False      False
# 9                                           Как бы нет  False      False
# 10   Да на выбор я уже не обращаю внимание я уже до...  False      False
# 11                               Что для вас приоритет  False      False
# 12                       Поэтому типа много параметров  False      False
# 13   Выбор не выбор есть история сотрудничества кот...  False      False
# 14   А работаем мы там а уже давно а почему звоните...  False      False
# 15   Ну у вас срок заканчивается поэтому мы набрали...  False      False
# 16   Совершенно верно да и вот так вот делает еще 5...  False      False
# 17                  И спрашивают продвигают продлевать  False      False
# 18   Ну вот я просто каждый раз удивляюсь почему не...  False      False
# 19   Хирам работает вот если вы хотите меня заполучить  False      False
# 20                       А в следующий раз как клиента  False      False
# 21   Сделайте мне 3 звонка в следующий период и спр...  False      False
# 22                                 Сделайте что нибудь  False      False
# 23   Незначительная но бесплатная и покажите свою к...  False      False
# 24   Как мне выбирать вас по каким параметрам потом...  False      False
# 25                          + месяц 2 3 все что угодно  False      False
# 26   Ну лояльности спрашивается 2 месяц не показыва...  False      False
# 27            Последний момент с предложением продлить  False      False
# 28                  А вот компания в которой я работаю  False      False
# 29   А так нет не только поэтому просто я обратила ...  False      False
# 30   А как будет недостаточно хорошие качественные ...  False      False
# 31   И меня все исключительно за то что вы мне как ...  False      False
# 32                                                 Ага  False      False
# 33                                                  Да  False      False
# 34   А если вы 19 являетесь то лучше то идти бесплатно  False      False
# 35   Слушайте очень сложно сказать потому что видже...  False      False
# 36                                          Ага хорошо  False      False
# 37   А настроены подключены от разных компаний поэт...  False      False
# 38   Не могу сказать я прошу прощения просто я да т...  False      False
# 39   А а да но ну действительно это так то что я ск...  False      False
# 40                                Э стоп вот там самый  False      False
# 41   Полтора года и меня все время действительно уд...  False      False
# 42   А просто извините свой подход немножко в целом...  False      False
# 43                                       Особо не дает  False      False
# 44   Контакты с клиентами вне формате их завершения...  False      False
# 45   Индивидуальным поэтому не все то есть сотрудни...  False      False
# 46                  Потому что вы звоните и ну то есть  False      False
# 47   Смотрите у меня есть история годичная работа с...  False      False
# 48                   О сопровождении они не только там  False      False
# 49                   Предлагают и у меня нареканий нет  False      False
# 50                          Это хорошая компания и 110  False      False
# 51                                  А компании которые  False      False
# 52                                                   И  False      False
# 53   То есть я не понимаю как вот просто подумайте ...  False      False
# 54                        Должны изменить свое решение  False      False
# 55                       По отношению к вашей компании  False      False
# 56   То есть у меня есть годичная история работы бе...  False      False
# 57     И вот менеджеры которые мне звонят и предлагают  False      False
# 58                                   Пробить через них  False      False
# 59   По какой причине я должен принять решение в ва...  False      False
# 60                               Переключен просто нет  False      False
# 61                                                Есть  False      False
# 62          Да мы услышали вас спасибо за рекомендации  False      False
# 63               Да да есть такая штуковина ну то есть  False      False
# 64                                  Получается так что  False      False
# 65       Из конверсии той базы которую вы обзваниваете  False      False
# 66   Скорее всего вы получите в контракт людей у ко...  False      False
# 67                         Либо у кого его вообще нету  False      False
# 68   Ну не факт что вы не можете получить допустим ...  False      False
# 69                                          В контакте  False      False
# 70                        Да делайте аудиты ну то есть  False      False
# 71                                     Там для вас это  False      False
# 72               Вообще копейки и не так много времени  False      False
# 73   А давайте рекомендации и тогда но если эти рек...  False      False
# 74   Больше и та компания которая сейчас работает н...  False      False
# 75                                                  Да  False      False
# 76                       Ну то есть это как бы простой  False      False
# 77   Вот понимаю да но дело в том что в основном да...  False      False
# 78   Такой простой шаг который в принципе можете де...  False      False
# 79          Э ну я не понимаю почему и никто не делает  False      False
# 80                                                Алло  False      False
# 81   А вот эти честно ну я просто уже забиваю со сч...  False      False
# 82                По счету это компания которая звонит  False      False
# 83                                              У меня  False      False
# 84                                      Решать договор  False      False
# 85                                      И вот за месяц  False      False
# 86                   Завершения мне звонят из компании  False      False
# 87                         И на 15 честно это вызывает  False      False
# 88                                 То что я не понимаю  False      False
# 89    Что хотите услышать но исключительно если только  False      False
# 90                            Да у меня по случаю есть  False      False
# 91                                                 Ага  False      False
# 92                              Необходимо обзванивать  False      False
# 93                                                 Ага  False      False
# 94   Хорошо я данную информацию тогда зафиксирую пе...  False      False
# 95   Ну просто подумайте подумайте вашей командой к...  False      False
# 96   Потому что это ну вот эти звонки за месяц до о...  False      False
# 97   Мне конечно интересно какая у вас конверсия та...  False      False
# 98                           Сколько людей соглашаются  False      False
# 99                                         Ну опять же  False      False
# 100                  Тем более если у вас есть виджеты  False      False
# 101      Если нет бесплатно если у вас видно а кто ваш  False      False
# 102    Это все можете использовать для вашей же пользы  False      False
# 103  Честно я не понимаю как у вас в продаже если ч...  False      False
# 104                                          Никто вот  False      False
# 105                                Да спасибо огромное  False      False
# 106            И вам спасибо большое за обратную связь  False      False
# 107                                                Угу  False      False
# 108                         Всего хорошего до свидания  False      False
# 109                Да здравствуйте когда заканчивается  False      False
# 110                                  Алло здравствуйте   True      False
# 111  Меня зовут ангелина компания диджитал бизнес з...  False       True
# 112               А так у вас заканчивается 25 февраля  False      False
# 113                             На полгода минимальный  False      False
# 114   25 февраля минимальный срок продления какой есть  False      False
# 115                 А у вас сейчас 8 базовый правильно  False      False
# 116                    Сейчас секунду 6 месяцев у меня  False      False
# 117  Сколько будет стоить на текущее количество пол...  False      False
# 118                                                Что  False      False
# 119                   8 пользователей указан правильно  False      False
# 120          Не знаю не знаю сейчас посмотрю но у меня  False      False
# 121                                                Угу  False      False
# 122                 1 2 3 4 5 у меня вообще 5 активных  False      False
# 123                   Мне пока больше не надо наверное  False      False
# 124                           Так сейчас секунду 1 2 3  False      False
# 125  65 а нет не там еще 1 2 3 4 5 нет правильно ну...  False      False
# 126  Нашей да а тариф базовый на 6 месяцев это 17964 р  False      False
# 127  Так 6 пользователей еще раз скажите пожалуйста...  False      False
# 128                                           Да 17964  False      False
# 129  564 р тогда такой вопрос и это допустим сейчас...  False      False
# 130  Да конечно вам просто нужно будет зайти в наст...  False      False
# 131                                               Алло  False      False
# 132  А а вот вверху у вас там будет как настройки з...  False      False
# 133  Сейчас прямо здесь скажите пожалуйста в пользо...  False      False
# 134                                      Да ну я здесь  False      False
# 135                                        И там будет  False      False
# 136       Ну вот сейчас секунду тут есть фильтр сейчас  False      False
# 137  Да вот где раздел как для админа там вам нужно...  False      False
# 138                                                Угу  False      False
# 139  Все все все сейчас активные пользователи и не ...  False      False
# 140  5 пользователей да сейчас я тогда проверю по в...  False      False
# 141                                       Так ну 1 2 3  False      False
# 142              У меня кстати также 5 5 пользователей  False      False
# 143                                Да сейчас 783-67-02  False      False
# 144  Так в очень странно мне просто указано 8 может...  False      False
# 145              А могли бы назвать ваш номер аккаунта  False      False
# 146                                783-67-02 правильно  False      False
# 147                                                 Да  False      False
# 148           Угу да сейчас 1 секунду я посмотрю тогда  False      False
# 149                    По вашему техническому кабинету  False      False
# 150  Так да по партнерскому у вас 5 пользователей в...  False      False
# 151                                      25 февраля да  False      False
# 152                        Все то есть как стандартная  False      False
# 153              Да у вас 25 февраля заканчивается угу  False      False
# 154  Хорошо я так подумаю вот и там дальше с вами с...  False      False
# 155  Угу хорошо я тогда вам информацию продублирую ...  False      False
# 156                А куда вам можно на ватсап например  False      False
# 157                             Нет ну можете на почту  False      False
# 158  Давайте тогда почту проверим инфо собачка эра ...  False      False
# 159             Самое только вместо инфо денис дэ е эн  False      False
# 160                                                Угу  False      False
# 161                                         И с точкой  False      False
# 162  Угу да вижу я эту почту хорошо тогда исправлю ...  False      False
# 163                                        До свидания  False      False
# 164                                               Алло  False      False
# 165                                       Здравствуйте  False      False
# 166                                  Алло здравствуйте   True      False
# 167  Меня зовут ангелина компания диджитал бизнес з...  False       True
# 168     А нет я еще не отправляла я решила вам набрать  False      False
# 169                         Ну разговаривать удобно да  False      False
# 170  Удобно вам сейчас говорить что я вам так расск...  False      False
# 171  Угу хорошо а вы сейчас подскажите по каким кри...  False      False
# 172               Так цена и эти индексации какие есть  False      False
# 173  Угу я поняла ну по стоимости везде одинаковые ...  False      False
# 174                      Да цена у всех одинаковая там  False      False
# 175  Поэтому могу сказать вот по преимуществам то е...  False      False
# 176                   Так ваша компания как называется  False      False
# 177                                    Диджитал бизнес  False      False
# 178                              Здесь же это у бизнес  False      False
# 179                                  Так там на севере  False      False
# 180                                                Так  False      False
# 181                                        Да ага вижу  False      False
# 182         Я вам еще раз говорю на ватсап предложение  False      False
# 183                                                Угу  False      False
# 184  Вот и смотрите на счет кэшбэка то что у вас кэ...  False      False
# 185                                                Так  False      False
# 186  Контроль например отказов то есть только для в...  False      False
# 187  У вас будут окошки там например на следующей н...  False      False
# 188                               Вы нашли да наш сайт  False      False
# 189                                   Подсветка сделок  False      False
# 190                                           Да да да  False      False
# 191                                                Угу  False      False
# 192                       Так значит у вас пишет и все  False      False
# 193  А подскажите тогда что вам нужно чтобы вы могл...  False      False
# 194                                    И что нам нужно  False      False
# 195                                                 Да  False      False
# 196                     Нам нужна интеграция с ватсапа  False      False
# 197                                                Угу  False      False
# 198                                                Угу  False      False
# 199                     Нам нужна этот удаление дублей  False      False
# 200                                   И нам нужно этот  False      False
# 201                                     Виджет который  False      False
# 202  Как вот так сейчас сейчас я вам еще точно скаж...  False      False
# 203                     Потом нам нужен виджет который  False      False
# 204                А сделать обязательно несколько раз  False      False
# 205                               Группировка полей да  False      False
# 206            Не не не грузируется делает обязательно  False      False
# 207                                А выделение на диск  False      False
# 208                                                Угу  False      False
# 209                                                 Да  False      False
# 210  А ну вот насчет выделения потом подсветки это ...  False      False
# 211                                       Пока что так  False      False
# 212                                   Угу понял хорошо  False      False
# 213  С кэшбэка у вас 20% идет от суммы которую опла...  False      False
# 214                                              Вот а  False      False
# 215                             А вы мне можете помочь  False      False
# 216                                  Не подскажете вот  False      False
# 217                                       Коммерческая  False      False
# 218              Да конечно вам на ватсап или на почту  False      False
# 219                                     Можете скинуть  False      False
# 220                                       Коммерческая  False      False
# 221                                                 Не  False      False
# 222                                       Угу на почту  False      False
# 223                               Можно на подключится  False      False
# 224                                      Ну вы мне это  False      False
# 225  Так давайте тогда проверим смотрите тут просто...  False      False
# 226                           Да да да на почте меньше  False      False
# 227                                            Нет нет  False      False
# 228                                    Сапаров собачка  False      False
# 229              А вот астана собачка ираклас точка кз  False      False
# 230                               Она нет тоже нету да  False      False
# 231                                            Еще раз  False      False
# 232                           Жесупов собачка аэропорт  False      False
# 233                                                Угу  False      False
# 234                          Или вы мне напишите новое  False      False
# 235  Не перепутала оставлю тогда на ватсап хорошо а...  False      False
# 236  Угу у нас еще неделя но давайте до среды решим...  False      False
# 237                                                Угу  False      False
# 238                                                Так  False      False
# 239        У вас в любое время есть с какого по какого  False      False
# 240                                            Что что  False      False
# 241  А в любое время хорошо тогда я аналитику по эт...  False      False
# 242                                                Угу  False      False
# 243                                         Угу хорошо  False      False
# 244                                Напишу что будет да  False      False
# 245                                                Угу  False      False
# 246  Хорошо тогда сейчас вам отправлю и звоните на ...  False      False
# 247                                         Угу хорошо  False      False
# 248                                         Все хорошо  False      False
# 249                                        Добрый день  False      False
# 250                           Алло дмитрий добрый день   True      False
# 251  Добрый меня максим зовут компания китобизнес у...  False       True
# 252                                          Да удобно  False      False
# 253  Да дмитрий вот мне моя коллега анастасия подск...  False      False
# 254                                А задача в общем то  False      False
# 255                       Стоит из чего сейчас секунду  False      False
# 256                                                Угу  False      False
# 257                                            В общем  False      False
# 258    Настроить воронки как бы и все такое я могу сам  False      False
# 259              Вот и даже сделать этого сэйл с ботом  False      False
# 260                Очень важно я думаю вот например да  False      False
# 261                                  Очень важно чтобы  False      False
# 262                                            Я думаю  False      False
# 263  Вот например я увидел обновление инбокс да поя...  False      False
# 264  Вот там сохранится прям сейчас и сразу мессенджер  False      False
# 265                                                 Да  False      False
# 266  Да абсолютно все то есть это единое такое окно...  False      False
# 267                                                Угу  False      False
# 268  Так а вот подскажите пожалуйста может быть про...  False      False
# 269                                            Я понял  False      False
# 270                                                Так  False      False
# 271                                       Что есть еще  False      False
# 272                              Транспортная компания  False      False
# 273  Транспортная компания хорошо а у вас уже вот в...  False      False
# 274  Ну смотрите мы планируем это все настраивать и...  False      False
# 275  Да но если мы будем прям настраивать вам серым...  False      False
# 276  Ну давайте знаете как мы сделаем что в любом с...  False      False
# 277                           Ну давайте знаете как мы  False      False
# 278                                                Угу  False      False
# 279            Я сначала сам попробую когда это уделал  False      False
# 280  А потом уже если что то я там подкорректироват...  False      False
# 281                  Если это за деньги в любом случае  False      False
# 282  Да нет конечно не сложно да ну смотрите да мы ...  False      False
# 283                                                Угу  False      False
# 284  Вот ну смотрите здесь наверное вот с точки зрения  False      False
# 285  А самого внедрения процесса ну я я бы вам реко...  False      False
# 286                                                Угу  False      False
# 287                                            Давайте  False      False
# 288                     Чтобы пустой разговор не вести  False      False
# 289                Мы с вами созвонимся с понедельника  False      False
# 290  Чтобы как бы это с руководителем почему то пришли  False      False
# 291                                                Угу  False      False
# 292                                             Хорошо  False      False
# 293              Давайте давайте так тогда наберем вас  False      False
# 294                                       За это время  False      False
# 295                     А в какое время вы перезвоните  False      False
# 296               А скажите когда удобно так и наберем  False      False
# 297                        Давайте часов в 11 наверное  False      False
# 298                11 да смогу набрать в 11 наберу вас  False      False
# 299                                     Угу все хорошо  False      False
# 300  Угу все хорошо да понедельника тогда всего доб...  False      False
# 301                                     Да до свидания  False      False
# 302                                               Алло  False      False
# 303                                               Алло  False      False
# 304                                             Добрый  False      False
# 305  Вот по виду платежи пообщаться помните мы вот ...  False      False
# 306                                                Угу  False      False
# 307                                   Ну в принципе да  False      False
# 308  Я понял ну мы хотели бы просто предложить тако...  False      False
# 309                                                Угу  False      False
# 310  Готовы будем для вашего клиента это использова...  False      False
# 311  Наверное в рамках недели полторы наверное займ...  False      False
# 312                            А на сколько можно идти  False      False
# 313  Понятно а оплата на сколько должна быть на это...  False      False
# 314                      Да мы на год принимаем оплату  False      False
# 315                                                Угу  False      False
# 316                                             Да так  False      False
# 317                                 Давайте я предложу  False      False
# 318  Хорошо и вы имеете ввиду доработку какую это к...  False      False
# 319  А вот а ну вот помните айдар вам не подходило ...  False      False
# 320     Там что как галочки просто вылезли да читались  False      False
# 321                                                Угу  False      False
# 322     Ну не только задача эти под под не запускается  False      False
# 323                 Ну вот вот вот им же главное чтобы  False      False
# 324  А я понял ну да да да тогда вот вот эти вот ве...  False      False
# 325  Клиентам уходило напоминание об очередном платеже  False      False
# 326                                                Угу  False      False
# 327                     Хорошо я дам ну да да обсудите  False      False
# 328             А в какой форме это вот ответ возьмите  False      False
# 329  А если про саму форму ну то есть вы получите т...  False      False
# 330                                       Если что угу  False      False
# 331                                             Ну вот  False      False
# 332  Хорошо я понял да у меня с ним связь будет в п...  False      False
# 333                                            Давайте  False      False
# 334  Все тогда а вас когда вам когда лучше тогда на...  False      False
# 335  Во вторник все ну с вами да тогда до вторника ...  False      False
# 336                                 Угу да до свидания  False      False
# 337                                               Алло  False      False
# 338                                   Да это анастасия  False       True
# 339  Смотрите мы сейчас уже нашли как бы да мы всю ...  False      False
# 340                                                Угу  False      False
# 341  Вот мы просто нашли сами сейчас всю базу вот э...  False      False
# 342                    Тогда переведите на специалиста  False      False
# 343       Так да да хорошо смотрите давайте по порядку  False      False
# 344                                             Хорошо  False      False
# 345                                              Давай  False      False
# 346  А вы сейчас загружаете всю базу в эксель а но ...  False      False
# 347                                                 Да  False      False
# 348  Ну мы их мы их да мы их вы да мы их в эксель з...  False      False
# 349                                                Угу  False      False
# 350  До этого мы сейчас посмотрели там неправильно ...  False      False
# 351  Да понимаю вас смотрите но вы вы же понимаете ...  False      False
# 352                                     Да да да да да  False      False
# 353  Все хорошо я вас поняла тогда вы хотите сейчас...  False      False
# 354                                                 Да  False      False
# 355                                     Да да да да да  False      False
# 356  Так хорошо здесь вас поняла говорите какой у в...  False      False
# 357                                       Вот у вашего  False      False
# 358  Да да да здравствуйте анастасия меня слышно да...  False      False
# 359                                          Да слышно  False      False
# 360  Отлично мне нужно узнать каким образом я смогу...  False      False
# 361                               На бесплатной основе  False      False
# 362                          Смотрите по поводу тарифа  False      False
# 363                         Вот и какой тариф подойдет  False      False
# 364  Нет смотрите мне я понимаю что там что то подк...  False      False
# 365  По поводу тарифов лицензии отдельно виджет отд...  False      False
# 366                        Сейчас вам ничего не мешает  False      False
# 367  Просто продиктуйте лицензию чтобы у вас начало...  False      False
# 368               А по поводу виджетов я вам сейчас ну  False      False
# 369                            Вы мне дадите ваш номер  False      False
# 370  С вами уже свяжется человек который непосредст...  False      False
# 371  Но там они уже отдельно подключаются то есть я...  False      False
# 372  Отдельно определенный какой то тариф то есть э...  False      False
# 373  Конкретно под ваш бизнес разговаривать и вам у...  False      False
# 374                        Смотрите а по поводу тарифа  False      False
# 375  При каком тарифе будет работать этот виджет ну...  False      False
# 376  Ну виджеты есть часть виджетов которые не рабо...  False      False
# 377                                           Да да да  False      False
# 378  Ну вот вам сейчас если вы например перейдете с...  False      False
# 379  По поводу виджетов они также подстраиваются по...  False      False
# 380                                              Да да  False      False
# 381                      И на 1 пользователя правильно  False      False
# 382                                    Да да все верно  False      False
# 383                                                Угу  False      False
# 384                                             Так ну  False      False
# 385  Тогда вот скажите если у нас 1 пользователь ра...  False      False
# 386  С учетом 2 месяца я так понимаю вот здесь напи...  False      False
# 387  У вас получится всего в сумме 13 месяцев там о...  False      False
# 388                                              Ага и  False      False
# 389  Вот вот смотрите мы сейчас в этом ну как бы в ...  False      False
# 390  0 9 990 все верно с нами точно такая же цена т...  False      False
# 391               1 год если расширенный выходит 9 900  False      False
# 392                                 2 месяца в подарок  False      False
# 393                                                Так  False      False
# 394  А ну вы как вы подключаете и через ваш как сер...  False      False
# 395                        А поддержка то есть там еще  False      False
# 396                                                Ряд  False      False
# 397                         Прибудет какой я вам звоню  False      False
# 398  Да все верно то есть я вам просто сейчас выста...  False      False
# 399                    Ну понятно вы просто посредники  False      False
# 400          Вы оплачиваете и нам мы потом ама то есть  False      False
# 401  За лицензию у нас цены точно такие же как и ва...  False      False
# 402                           Да мы партнер который да  False      False
# 403                  Да да и когда счет будет 9 900 да  False      False
# 404                                               9990  False      False
# 405                                                 13  False      False
# 406                                                 Да  False      False
# 407                      Да за 13 месяцев да или за 14  False      False
# 408                                       Да все верно  False      False
# 409                                                113  False      False
# 410  Ну смотрите там уже если у вас по амо будут ка...  False      False
# 411  А в поддержку что вот ну как бы ваши будут вхо...  False      False
# 412  Нет это я понимаю это да это это я все понимаю...  False      False
# 413  Бывает то что там не знаю что то не прогружает...  False      False
# 414                                                Они  False      False
# 415                       Либо могут отвечать неделями  False      False
# 416                                                 Да  False      False
# 417  А если мы к вам будем вот смотрите мы сейчас н...  False      False
# 418  Вот смотрите у нас вот я вам прописывала наши ...  False      False
# 419  Вы можете ну например если мы сейчас начнем чт...  False      False
# 420  И здесь прописано то что мы за вами закрепляем...  False      False
# 421  А там раз в неделю будет как то диагностироват...  False      False
# 422                                                Угу  False      False
# 423                То есть здесь мы за здесь мы с вами  False      False
# 424  Ну вот это вот это хорошо просто понимаете вых...  False      False
# 425  Вот так да я вас понимаю и мы знаем об этой си...  False      False
# 426  Блин а когда ему говоришь так мы же в начале п...  False      False
# 427  И вот это как то не корректно мне кажется ну я...  False      False
# ...
# 447  Вот и после этого он уже вам даст рекомендации...  False      False
# 448  То есть это уже будете обсуждать с ним и если ...  False      False
# 449                                    Я понял я понял  False      False
# 450                               Вопрос с ним поэтому  False      False
# 451  Сейчас со мной с претензиями закончились ну в ...  False      False
# 452  Ну вы тогда высылайте тогда договор и высылайт...  False      False
# 453                                          Не знаешь  False      False
# 454                                                Угу  False      False
# 455                                               Алло  False      False
# 456  Ну вот смотрите сегодня уже вряд ли потому что...  False      False
# 457     А телефон тогда ну я не знаю он когда позвонит  False      False
# 458                                     Ну это понятно  False      False
# 459                                              Да да  False      False
# 460  Я думаю что завтра он с вами свяжется вы с ним...  False      False
# 461  Да тогда все высылайте так да и тогда в понеде...  False      False
# 462                               Так давайте диктуйте  False      False
# 463                                            9 0 4 9  False      False
# 464                                                Угу  False      False
# 465                                                2 9  False      False
# 466                                                Угу  False      False
# 467                                            9 9 7 7  False      False
# 468                                   Так проверим 9 0  False      False
# 469                                                Угу  False      False
# 470                                            4 9 2 9  False      False
# 471                                            9 9 7 7  False      False
# 472                                        Так дмитрий  False      False
# 473             Все записала тогда завтра ждите звонка  False      False
# 474                                          Да хорошо  False      False
# 475  По поводу виджетов и с ними уже обсудите конкр...  False      False
# 476  Все я вам высылаю счет и с вами на связи если ...  False      False
# 477                                    Спасибо спасибо  False      False
# 478     Да да тогда созвонимся ага спасибо вам давайте  False      False
# 479                     Ну до свидания хорошего вечера  False      False
#
#        Bye  Greet and bye
# 0    False           True
# 1    False           True
# 2    False           True
# 3    False           True
# 4    False           True
# 5    False           True
# 6    False           True
# 7    False           True
# 8    False           True
# 9    False           True
# 10   False           True
# 11   False           True
# 12   False           True
# 13   False           True
# 14   False           True
# 15   False           True
# 16   False           True
# 17   False           True
# 18   False           True
# 19   False           True
# 20   False           True
# 21   False           True
# 22   False           True
# 23   False           True
# 24   False           True
# 25   False           True
# 26   False           True
# 27   False           True
# 28   False           True
# 29   False           True
# 30   False           True
# 31   False           True
# 32   False           True
# 33   False           True
# 34   False           True
# 35   False           True
# 36   False           True
# 37   False           True
# 38   False           True
# 39   False           True
# 40   False           True
# 41   False           True
# 42   False           True
# 43   False           True
# 44   False           True
# 45   False           True
# 46   False           True
# 47   False           True
# 48   False           True
# 49   False           True
# 50   False           True
# 51   False           True
# 52   False           True
# 53   False           True
# 54   False           True
# 55   False           True
# 56   False           True
# 57   False           True
# 58   False           True
# 59   False           True
# 60   False           True
# 61   False           True
# 62   False           True
# 63   False           True
# 64   False           True
# 65   False           True
# 66   False           True
# 67   False           True
# 68   False           True
# 69   False           True
# 70   False           True
# 71   False           True
# 72   False           True
# 73   False           True
# 74   False           True
# 75   False           True
# 76   False           True
# 77   False           True
# 78   False           True
# 79   False           True
# 80   False           True
# 81   False           True
# 82   False           True
# 83   False           True
# 84   False           True
# 85   False           True
# 86   False           True
# 87   False           True
# 88   False           True
# 89   False           True
# 90   False           True
# 91   False           True
# 92   False           True
# 93   False           True
# 94   False           True
# 95   False           True
# 96   False           True
# 97   False           True
# 98   False           True
# 99   False           True
# 100  False           True
# 101  False           True
# 102  False           True
# 103  False           True
# 104  False           True
# 105  False           True
# 106  False           True
# 107  False           True
# 108   True           True
# 109  False           True
# 110  False           True
# 111  False           True
# 112  False           True
# 113  False           True
# 114  False           True
# 115  False           True
# 116  False           True
# 117  False           True
# 118  False           True
# 119  False           True
# 120  False           True
# 121  False           True
# 122  False           True
# 123  False           True
# 124  False           True
# 125  False           True
# 126  False           True
# 127  False           True
# 128  False           True
# 129  False           True
# 130  False           True
# 131  False           True
# 132  False           True
# 133  False           True
# 134  False           True
# 135  False           True
# 136  False           True
# 137  False           True
# 138  False           True
# 139  False           True
# 140  False           True
# 141  False           True
# 142  False           True
# 143  False           True
# 144  False           True
# 145  False           True
# 146  False           True
# 147  False           True
# 148  False           True
# 149  False           True
# 150  False           True
# 151  False           True
# 152  False           True
# 153  False           True
# 154  False           True
# 155  False           True
# 156  False           True
# 157  False           True
# 158  False           True
# 159  False           True
# 160  False           True
# 161  False           True
# 162   True           True
# 163   True           True
# 164  False           True
# 165  False           True
# 166  False           True
# 167  False           True
# 168  False           True
# 169  False           True
# 170  False           True
# 171  False           True
# 172  False           True
# 173  False           True
# 174  False           True
# 175  False           True
# 176  False           True
# 177  False           True
# 178  False           True
# 179  False           True
# 180  False           True
# 181  False           True
# 182  False           True
# 183  False           True
# 184  False           True
# 185  False           True
# 186  False           True
# 187  False           True
# 188  False           True
# 189  False           True
# 190  False           True
# 191  False           True
# 192  False           True
# 193  False           True
# 194  False           True
# 195  False           True
# 196  False           True
# 197  False           True
# 198  False           True
# 199  False           True
# 200  False           True
# 201  False           True
# 202  False           True
# 203  False           True
# 204  False           True
# 205  False           True
# 206  False           True
# 207  False           True
# 208  False           True
# 209  False           True
# 210  False           True
# 211  False           True
# 212  False           True
# 213  False           True
# 214  False           True
# 215  False           True
# 216  False           True
# 217  False           True
# 218  False           True
# 219  False           True
# 220  False           True
# 221  False           True
# 222  False           True
# 223  False           True
# 224  False           True
# 225  False           True
# 226  False           True
# 227  False           True
# 228  False           True
# 229  False           True
# 230  False           True
# 231  False           True
# 232  False           True
# 233  False           True
# 234  False           True
# 235  False           True
# 236  False           True
# 237  False           True
# 238  False           True
# 239  False           True
# 240  False           True
# 241  False           True
# 242  False           True
# 243  False           True
# 244  False           True
# 245  False           True
# 246  False           True
# 247  False           True
# 248   True           True
# 249  False           True
# 250  False           True
# 251  False           True
# 252  False           True
# 253  False           True
# 254  False           True
# 255  False           True
# 256  False           True
# 257  False           True
# 258  False           True
# 259  False           True
# 260  False           True
# 261  False           True
# 262  False           True
# 263  False           True
# 264  False           True
# 265  False           True
# 266  False           True
# 267  False           True
# 268  False           True
# 269  False           True
# 270  False           True
# 271  False           True
# 272  False           True
# 273  False           True
# 274  False           True
# 275  False           True
# 276  False           True
# 277  False           True
# 278  False           True
# 279  False           True
# 280  False           True
# 281  False           True
# 282  False           True
# 283  False           True
# 284  False           True
# 285  False           True
# 286  False           True
# 287  False           True
# 288  False           True
# 289  False           True
# 290  False           True
# 291  False           True
# 292  False           True
# 293  False           True
# 294  False           True
# 295  False           True
# 296  False           True
# 297  False           True
# 298  False           True
# 299  False           True
# 300   True           True
# 301  False           True
# 302  False          False
# 303  False          False
# 304  False          False
# 305  False          False
# 306  False          False
# 307  False          False
# 308  False          False
# 309  False          False
# 310  False          False
# 311  False          False
# 312  False          False
# 313  False          False
# 314  False          False
# 315  False          False
# 316  False          False
# 317  False          False
# 318  False          False
# 319  False          False
# 320  False          False
# 321  False          False
# 322  False          False
# 323  False          False
# 324  False          False
# 325  False          False
# 326  False          False
# 327  False          False
# 328  False          False
# 329  False          False
# 330  False          False
# 331  False          False
# 332  False          False
# 333  False          False
# 334  False          False
# 335   True          False
# 336  False          False
# 337  False          False
# 338  False          False
# 339  False          False
# 340  False          False
# 341  False          False
# 342  False          False
# 343  False          False
# 344  False          False
# 345  False          False
# 346  False          False
# 347  False          False
# 348  False          False
# 349  False          False
# 350  False          False
# 351  False          False
# 352  False          False
# 353  False          False
# 354  False          False
# 355  False          False
# 356  False          False
# 357  False          False
# 358  False          False
# 359  False          False
# 360  False          False
# 361  False          False
# 362  False          False
# 363  False          False
# 364  False          False
# 365  False          False
# 366  False          False
# 367  False          False
# 368  False          False
# 369  False          False
# 370  False          False
# 371  False          False
# 372  False          False
# 373  False          False
# 374  False          False
# 375  False          False
# 376  False          False
# 377  False          False
# 378  False          False
# 379  False          False
# 380  False          False
# 381  False          False
# 382  False          False
# 383  False          False
# 384  False          False
# 385  False          False
# 386  False          False
# 387  False          False
# 388  False          False
# 389  False          False
# 390  False          False
# 391  False          False
# 392  False          False
# 393  False          False
# 394  False          False
# 395  False          False
# 396  False          False
# 397  False          False
# 398  False          False
# 399  False          False
# 400  False          False
# 401  False          False
# 402  False          False
# 403  False          False
# 404  False          False
# 405  False          False
# 406  False          False
# 407  False          False
# 408  False          False
# 409  False          False
# 410  False          False
# 411  False          False
# 412  False          False
# 413  False          False
# 414  False          False
# 415  False          False
# 416  False          False
# 417  False          False
# 418  False          False
# 419  False          False
# 420  False          False
# 421  False          False
# 422  False          False
# 423  False          False
# 424  False          False
# 425  False          False
# 426  False          False
# 427  False          False
# 428  False          False
# 429  False          False
# 430  False          False
# 431  False          False
# 432  False          False
# 433  False          False
# 434  False          False
# 435  False          False
# 436  False          False
# 437  False          False
# 438  False          False
# 439  False          False
# 440  False          False
# 441  False          False
# 442  False          False
# 443  False          False
# 444  False          False
# 445  False          False
# 446  False          False
# 447  False          False
# 448  False          False
# 449  False          False
# 450  False          False
# 451  False          False
# 452  False          False
# 453  False          False
# 454  False          False
# 455  False          False
# 456  False          False
# 457  False          False
# 458  False          False
# 459  False          False
# 460  False          False
# 461  False          False
# 462  False          False
# 463  False          False
# 464  False          False
# 465  False          False
# 466  False          False
# 467  False          False
# 468  False          False
# 469  False          False
# 470  False          False
# 471  False          False
# 472  False          False
# 473  False          False
# 474  False          False
# 475  False          False
# 476  False          False
# 477  False          False
# 478  False          False
# 479   True          False
